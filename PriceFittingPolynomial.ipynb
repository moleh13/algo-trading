# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Define the ticker symbol and date range
ticker_symbol = "CRV-USD"
start_date = "2020-03-08"
end_date = "2024-03-08"

# Download historical data
crv_price_daily = yf.download(ticker_symbol, start=start_date, end=end_date)

# Just get the Close prices
crv_price_daily = crv_price_daily["Close"]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# Linear regression
x_values = np.arange(len(crv_price_daily))
m, c = np.polyfit(x_values, crv_price_daily, 1)

# Plot the linear regression line on the same graph
regression_line = m * x_values + c
plt.plot(crv_price_daily.index, regression_line, color='red', label=f'Linear Regression: y = {m:.2f}x + {c:.2f}')
plt.legend()

plt.show()

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# Quadratic regression
x_values = np.arange(len(crv_price_daily))
a, b, c = np.polyfit(x_values, crv_price_daily, 2)

# Plot the quadratic regression curve on the same graph
quad_regression_curve = a * x_values**2 + b * x_values + c
plt.plot(crv_price_daily.index, quad_regression_curve, color='orange', label=f'Quadratic Regression: y = {a:.2f}x^2 + {b:.2f}x + {c:.2f}')
plt.legend()

plt.show()

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# Cubic regression
x_values = np.arange(len(crv_price_daily))
a, b, c, d = np.polyfit(x_values, crv_price_daily, 3)

# Plot the cubic regression curve on the same graph
cubic_regression_curve = a * x_values**3 + b * x_values**2 + c * x_values + d
plt.plot(crv_price_daily.index, cubic_regression_curve, color='purple', label=f'Cubic Regression: y = {a:.2f}x^3 + {b:.2f}x^2 + {c:.2f}x + {d:.2f}')
plt.legend()

plt.show()

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# Quartic regression
x_values = np.arange(len(crv_price_daily))
a, b, c, d, e = np.polyfit(x_values, crv_price_daily, 4)

# Plot the quartic regression curve on the same graph
quartic_regression_curve = a * x_values**4 + b * x_values**3 + c * x_values**2 + d * x_values + e
plt.plot(crv_price_daily.index, quartic_regression_curve, color='green', label=f'Quartic Regression: y = {a:.2f}x^4 + {b:.2f}x^3 + {c:.2f}x^2 + {d:.2f}x + {e:.2f}')
plt.legend()

plt.show()

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# 40th degree polynomial regression
x_values = np.arange(len(crv_price_daily))
coefficients = np.polyfit(x_values, crv_price_daily, 40)

# Create the polynomial using np.polyval
polynomial_curve = np.polyval(coefficients, x_values)

# Plot the 40th degree polynomial regression curve on the same graph
plt.plot(crv_price_daily.index, polynomial_curve, color='brown', label=f'40th Degree Polynomial Regression')
plt.legend()

plt.show()
# Out:
# /Users/melihkarakose/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:3577: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Create a time series chart
plt.figure(figsize=(10, 6))
plt.plot(crv_price_daily.index, crv_price_daily, label="CRV-USD")
plt.title("CRV-USD Daily Closing Prices (2020-03-08 to 2024-03-08)")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)

# 40th degree polynomial regression
x_values = np.arange(len(crv_price_daily))
coefficients = np.polyfit(x_values, crv_price_daily, 40)

# Create the polynomial using np.polyval
polynomial_curve = np.polyval(coefficients, x_values)

# Plot the 40th degree polynomial regression curve on the same graph
plt.plot(crv_price_daily.index, polynomial_curve, color='brown', label=f'40th Degree Polynomial Regression')
plt.legend()

# Forecast future 3 months (90 days)
future_x_values = np.arange(len(crv_price_daily), len(crv_price_daily) + 91)
future_polynomial_curve = np.polyval(coefficients, future_x_values)

# Plot the forecasted values
plt.plot(pd.date_range(start=crv_price_daily.index[-1], periods=91, freq='D'), future_polynomial_curve, linestyle='dashed', color='blue', label='Forecast (3 months)')

plt.show()
# Out:
# /Users/melihkarakose/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:3577: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
