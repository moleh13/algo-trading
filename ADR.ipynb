# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start = "2024-01-01"
end = "2024-03-19"
ticker = "ARB11841-USD"
interval = "1d"
pd.options.display.float_format = '{:.4f}'.format

# %%
df = yf.download(ticker, start=start, end=end, interval=interval)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close      Volume
# Date
# 2024-01-01 1.5558 1.7391 1.5214 1.7352     1.7352   736600434
# 2024-01-02 1.7352 1.8313 1.7136 1.7716     1.7716  1105169921
# 2024-01-03 1.7716 2.0564 1.6976 1.9104     1.9104  3384321119
# 2024-01-04 1.9108 2.1093 1.8282 2.0122     2.0122  1702736214
# 2024-01-05 2.0111 2.0149 1.8413 1.9402     1.9402  1233240696
# ...           ...    ...    ...    ...        ...         ...
# 2024-03-14 2.1178 2.1178 1.9416 2.0148     2.0148   954399402
# 2024-03-15 2.0148 2.0313 1.8102 1.8854     1.8854   941997889
# 2024-03-16 1.8854 1.9533 1.7197 1.7590     1.7590  1037970776
# 2024-03-17 1.7590 1.7713 1.6240 1.7334     1.7334   779446750
# 2024-03-18 1.7342 1.7363 1.6003 1.6215     1.6215   890503800
#
# [78 rows x 6 columns]

# %%
df['Daily Range'] = df['High'] - df['Low']
df
# Out:
#              Open   High    Low  Close  Adj Close      Volume  Daily Range
# Date
# 2024-01-01 1.5558 1.7391 1.5214 1.7352     1.7352   736600434       0.2177
# 2024-01-02 1.7352 1.8313 1.7136 1.7716     1.7716  1105169921       0.1177
# 2024-01-03 1.7716 2.0564 1.6976 1.9104     1.9104  3384321119       0.3588
# 2024-01-04 1.9108 2.1093 1.8282 2.0122     2.0122  1702736214       0.2810
# 2024-01-05 2.0111 2.0149 1.8413 1.9402     1.9402  1233240696       0.1736
# ...           ...    ...    ...    ...        ...         ...          ...
# 2024-03-14 2.1178 2.1178 1.9416 2.0148     2.0148   954399402       0.1763
# 2024-03-15 2.0148 2.0313 1.8102 1.8854     1.8854   941997889       0.2210
# 2024-03-16 1.8854 1.9533 1.7197 1.7590     1.7590  1037970776       0.2335
# 2024-03-17 1.7590 1.7713 1.6240 1.7334     1.7334   779446750       0.1473
# 2024-03-18 1.7342 1.7363 1.6003 1.6215     1.6215   890503800       0.1360
#
# [78 rows x 7 columns]

# %%
average_daily_range = df['Daily Range'].mean()

print(f"The average daily range for {ticker} is {average_daily_range:.2f}")
# Out:
# The average daily range for ARB11841-USD is 0.15

# %%
# Create figure and subplots
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Daily Range on the first subplot
ax1.plot(df.index, df['Daily Range'], color='blue', linewidth=1, label='Daily Range')
ax1.set_xlabel('Date')
ax1.set_ylabel('Daily Range', color='blue')
ax1.tick_params('y', colors='blue')
ax1.legend(loc='upper left')

# Create a second y-axis for the Close prices
ax2 = ax1.twinx()
ax2.plot(df.index, df['Close'], color='red', linewidth=1, label='Close Price')
ax2.set_ylabel('Price', color='red')
ax2.tick_params('y', colors='red')
ax2.legend(loc='upper right')

# Title
plt.title(f"{ticker} Daily Range and Price")

# Show grid
plt.grid(True)

# Show the plot
plt.show()
